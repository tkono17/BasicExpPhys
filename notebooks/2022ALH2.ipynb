# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0.00,  2.50,  5.00,  7.50, 10.00, 12.50, 15.00, 17.50, 
              20.00, 22.50, 25.00, 27.50, 30.00, 32.50, 35.00, 37.50, 
              40.00, 42.50, 45.00, 47.50, 50.00, 52.50, 55.00, 57.50, 
              60.00, 62.50, 65.00, 67.50, 70.00, 72.50, 75.00, 77.50, 
              80.00, 82.50, 85.00, 87.50, 90.00, 92.50, 95.00, 97.50,])
y = np.array([-18.19, -17.75, -13.70, -14.61, -14.32, -11.52, -10.79, -9.03, 
              -9.07, -6.40, -5.12, -2.61, -2.83, -1.89, -0.09, -0.14, 
              3.02, 4.74,  3.73,  4.79,  5.39,  8.69,  9.41, 10.00, 
              10.65, 14.03, 14.83, 15.84, 19.00, 19.30, 21.04, 21.03, 
              24.07, 21.87, 25.30, 26.71, 26.00, 27.69, 30.60, 30.63, ])
ex = np.zeros(40)
ey = ex + 1.0
#
weights = 1.0/(ey*ey)
coef = np.polyfit(x, y, 1, w=weights)
appr = np.poly1d(coef)(x)
#
plt.errorbar(x, y, yerr=ey, fmt='o', markersize=3)
plt.plot(x, appr, color='black', linestyle=':')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# y = p0*x + p1
for i, x in enumerate(coef):
    print('parameter[%d] : %6.3f' % (i, x) )
#
# Out:
# parameter[0] :  0.505
# parameter[1] : -18.129

# %%
x = np.array([  0.00, 2.50, 5.00, 7.50,10.00,12.50,15.00,17.50,20.00,
              22.50,25.00,27.50,30.00,32.50,35.00,37.50,
              40.00,42.50,45.00,47.50,50.00,52.50,55.00,57.50,
              60.00,62.50,65.00,67.50,70.00,72.50,75.00,77.50,
              80.00,82.50,85.00,87.50,90.00,92.50,95.00,97.50,])
y = np.array([ -21.69, -24.66, -23.82, -27.76, -30.32, -30.17, -31.91, -32.44, 
              -34.57, -33.81, -34.25, -33.26, -34.83, -35.05, -34.21, -35.05, 
              -32.48, -31.16, -32.39, -31.36, -30.61, -26.96, -25.72, -24.40, 
              -22.85, -18.38, -16.29, -13.82, -9.00, -6.85, -3.08, -0.88,  
              4.57,  4.96, 11.17, 15.55, 18.00, 23.03, 29.47, 33.22, ])
ex = np.zeros(40)
ey = ex + 1.0
#
weights = 1.0/(ey*ey)
coef = np.polyfit(x, y, 2, w=weights)
appr = np.poly1d(coef)(x)
#
plt.errorbar(x, y, yerr=ey, fmt='o', markersize=3)
plt.plot(x, appr, color='black', linestyle=':')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# y = p0*x^2 + p1*x + p0
for i, x in enumerate(coef):
    print('parameter[%d] : %5.3f' % (i, x))
#
# Out:
# parameter[0] : 0.015
# parameter[1] : -0.892
# parameter[2] : -21.663

# %%
x = np.array([  0.00, 2.50, 5.00, 7.50,10.00,12.50,15.00,17.50,20.00,
              22.50,25.00,27.50,30.00,32.50,35.00,37.50,
              40.00,42.50,45.00,47.50,50.00,52.50,55.00,57.50,
              60.00,62.50,65.00,67.50,70.00,72.50,75.00,77.50,
              80.00,82.50,85.00,87.50,90.00,92.50,95.00,97.50,])
y = np.array([ -21.69, -24.66, -23.82, -27.76, -30.32, -30.17, -31.91, -32.44, 
              -34.57, -33.81, -34.25, -33.26, -34.83, -35.05, -34.21, -35.05, 
              -32.48, -31.16, -32.39, -31.36, -30.61, -26.96, -25.72, -24.40, 
              -22.85, -18.38, -16.29, -13.82, -9.00, -6.85, -3.08, -0.88,  
              4.57,  4.96, 11.17, 15.55, 18.00, 23.03, 29.47, 33.22, ])
ex = np.zeros(40)
ey = ex + 1.0
#
weights = 1.0/(ey*ey)
coef = np.polyfit(x, y, 2, w=weights)
appr = np.poly1d(coef)(x)
#
plt.errorbar(x, y, yerr=ey, fmt='o', markersize=3)
plt.plot(x, appr, color='black', linestyle=':')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# y = p0*x^2 + p1*x + p0
for i, x in enumerate(coef):
    print('parameter[%d] : %5.3f' % (i, x))
#
# Out:
# parameter[0] : 0.015
# parameter[1] : -0.892
# parameter[2] : -21.663

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

x = np.array([  0.00, 2.50, 5.00, 7.50,10.00,12.50,15.00,17.50, 
              20.00,22.50,25.00,27.50,30.00,32.50,35.00,37.50,
              40.00,42.50,45.00,47.50,50.00,52.50,55.00,57.50,
              60.00,62.50,65.00,67.50,70.00,72.50,75.00,77.50,
              80.00,82.50,85.00,87.50,90.00,92.50,95.00,97.50,])
y = np.array([  0.00,  0.00,  1.90,  0.00,  0.00,  0.77,  0.60,  1.67,  
              1.21,  3.86,  5.63,  9.29, 10.99, 14.76, 20.36, 25.08, 
              33.91, 42.00, 47.75, 55.57, 62.45, 71.04, 75.59, 78.15, 
              78.65, 79.68, 76.01, 70.69, 66.06, 57.58, 50.06, 40.79, 
              34.96, 24.59, 20.74, 15.86,  9.83,  7.09,  6.36,  3.39, ])
ex = np.zeros(40)
ey = ex + 1.0
#
def gaussian_func(x, A, mu, sigma):
    return A/(sigma*np.sqrt(2.0*np.pi)) * np.exp(- (x-mu)**2/(2*sigma**2))
weights = 1.0/(ey*ey)
pars, cov = curve_fit(gaussian_func, x, y, p0=(50.0, 50.0, 10.0))
appr = gaussian_func(x, pars[0], pars[1], pars[2])
#
plt.errorbar(x, y, yerr=ey, fmt='o', markersize=3)
plt.plot(x, appr, color='black', linestyle=':')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
for i, x in enumerate(pars):
    print('parameter[%d] : %6.3f' % (i, x) )
#
# Out:
# parameter[0] : 3027.455
# parameter[1] : 60.151
# parameter[2] : 15.116
